# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import math
import pathlib
import re
import json
from pprint import pprint

# %%
# Color style similar to ppt color scheme
plt.style.use('seaborn-colorblind')

#Latex Default Font
plt.rc('font', family='serif') 
plt.rc('font', serif='Latin Modern Roman')
matplotlib.rcParams.update({'font.size': 16})

# %%
pd.set_option('display.max_columns', None, 'display.max_rows', None)

# %%
def make_hatches(ax, df):
    hatches = [h*len(df.index) for h in [['.'], ['--'], ['x'], ['\\'], ['||'], ['+'], ['O'], ['o'], ['//']]]
    hatches = sum(hatches, [])

    if len(hatches) < len(ax.patches):
        print("Not enough hatches defined")
        
    for i,bar in enumerate(ax.patches):
        bar.set_hatch(hatches[i])
#     ax.legend()

# %% [markdown]
# # Loading Data

# %%
with open('results.json', 'r') as f:
    raw = json.load(f)

# just lists of dicts of all results
kaasRaw = [ r for r in raw if r['client'] == 'kaas' ]
faasRaw = [ r for r in raw if r['client'] == 'faas' ]
localRaw = [ r for r in raw if r['client'] == 'local' ]

kaasDF = pd.DataFrame(kaasRaw)
faasDF = pd.DataFrame(faasRaw)
localDF = pd.DataFrame(localRaw)

# faasDF.filter(regex="t_requestEncode|t_requestDecode|t_responseEncode|t_responseDecode")
# localDF.filter(regex=controlPattern).sum(axis='columns')

# %% [markdown]
# ## Create some standard fields

# %% [markdown]
# There are a few core fields we use in analysis, others are there 'just in case'.
#
# Plotted Fields:
# * **t_e2e**: Time taken for a single invocation of the function, including queueing time, preprocessing, sgemm, etc.
# * **t_data_layer**: Time spent reading/writing to the host data layer (e.g. ray plasma store)
# * **t_cuda_mm**: Time spent in cudaMalloc/Free
# * **t_cuda_copy**: Time spent copying data on/off the GPU
# * **t_kernel**: Time spent actually running GPU code
# * **t_other**: All other time
#
# Common Fields:
# * **t_e2e**: Time taken for a single invocation of the function, including queueing time, preprocessing, sgemm, etc.
# * **t_hostCopy**: Time spent in the data layer (kaas only)
# * **t_pre**: Preprocessing time, including any overheads.
# * **t_post**: Time in the post processing function.
#
# Derived Standard Fields:
# * **t_uncounted**: Time that was not specifically measured
# * **t_controlPlane**: Time taken for the system to move commands around, including serializing/deserializing requests/responses. (kaas only)
# * **t_kernInit**: Time taken for the GPU part to initialize (only valid for cold starts).
# * **t_kernel**: Total time spent actually invoking the GPU kernels.
# * **t_cudaMM**: cudaMalloc/Free (kaas only)
# * **t_cudaCopy**: cudaMemcpy (kaas only)
#
# Included Standard Fields:
# * **model_type**: tvm or kaas (tvm is actually all non-kaas until we stop being lazy and rename it)
# * **model**: which workload
# * **warm**: Every experiment has two sets of stats, one warm and one cold.
# * **policy**: Which scheduling policy was used

# %%
# These are the major disjoint timing categories, ideally these will cover t_e2e more or less completely
# we use t_preprocess_configured rather than t_preprocess because the overheads are accounted for in the other measurements
keyTimes = ['t_preInit', 't_kernInit', 't_kv', 't_kernel', 't_preprocess_configured', 't_cudaMM', 't_cudaCopy', 't_controlPlane', 't_uncounted']
overheadCols = [ m for m in keyTimes if m not in ['t_kernel', 't_preprocess_configured']]
configCols = ['mode', 'client', 'warm', 't_preprocess_configured', 'preInline', 'matDim']

# %%
faasDF['t_preInit'] = faasDF['client:prefunc:t_init']
faasDF['t_kernInit'] = faasDF['client:remfunc:t_init'] + faasDF['client:remfunc:worker:t_kernelLoad']
kaasDF['t_preInit'] = kaasDF['client:prefunc:t_init']
kaasDF['t_kernInit'] = kaasDF['client:kaas:worker:t_kernelLoad']
localDF['t_kernInit'] = localDF['client:t_kernelLoad']
localDF['t_preInit'] = 0


faasDF['t_preprocess'] = faasDF['client:remfunc:worker:t_preprocess'].where(
    faasDF['preInline'], faasDF['client:t_preprocess'])
kaasDF['t_preprocess'] = kaasDF['client:prefunc:t_invoke']
localDF['t_preprocess'] = localDF['client:t_preprocess']

for df in [kaasDF, faasDF, localDF]:
    df['t_e2e'] = df['client:t_e2e']
    
    # flatten everything related to the kv for total kv time
    df['t_kv'] = df.filter(regex=".*:kv.*").sum(axis='columns')
    df['t_kv'] = df['t_kv'].fillna(0)
    
    df['t_cudaCopy'] = df.filter(regex=".*:t_dtoh|.*:t_htod").sum(axis='columns')
    df['t_cudaCopy'].fillna(0)
    
    df['t_zero'] = df.filter(regex=".*t_zero.*").sum(axis='columns')
    df['t_kernel'] = df.filter(regex=".*:t_kernel$")
    df['t_cudaMM'] = df.filter(regex=".*:t_cudaMM$")
    
    df['t_controlPlane'] = df.filter(regex="t_requestEncode|t_requestDecode|t_responseEncode|t_responseDecode").sum(axis='columns')
    
    df.fillna(0, inplace=True)
    
kaasDF['t_cudaMM'] += kaasDF['client:kaas:worker:t_hostMM']

# There are gaps in the profiling, particularly in KaaS
for df in [kaasDF, faasDF, localDF]:
    allCounted = [ t for t in keyTimes if t != 't_uncounted']
    df['t_uncounted'] = df['t_e2e'] - df[allCounted].sum(axis='columns')
    
for df in [kaasDF, faasDF, localDF]:
    df['pctOverhead'] = (df[overheadCols].sum(axis='columns') / df['t_e2e']) * 100

# %% [markdown]
# # Simple Analysis / Sanity Checking

# %%
faasDF[configCols + ['t_kernel', 't_kv']]
# Out:
#        mode client   warm  t_preprocess_configured  preInline  matDim  \
# 0    direct   faas  False                      0.0      False    1024
# 1    direct   faas   True                      0.0      False    1024
# 2    direct   faas  False                     20.0       True    1024
# 3    direct   faas   True                     20.0       True    1024
# 4    direct   faas  False                     20.0      False    1024
# 5    direct   faas   True                     20.0      False    1024
# 6    direct   faas  False                    150.0       True    1024
# 7    direct   faas   True                    150.0       True    1024
# 8    direct   faas  False                    150.0      False    1024
# 9    direct   faas   True                    150.0      False    1024
# 10   direct   faas  False                      0.0      False    8192
# 11   direct   faas   True                      0.0      False    8192
# 12   direct   faas  False                   9500.0       True    8192
# 13   direct   faas   True                   9500.0       True    8192
# 14   direct   faas  False                   9500.0      False    8192
# 15   direct   faas   True                   9500.0      False    8192
# 16   direct   faas  False                  76000.0       True    8192
# 17   direct   faas   True                  76000.0       True    8192
# 18   direct   faas  False                  76000.0      False    8192
# 19   direct   faas   True                  76000.0      False    8192
# 20  process   faas  False                      0.0      False    1024
# 21  process   faas   True                      0.0      False    1024
# 22  process   faas  False                     20.0       True    1024
# 23  process   faas   True                     20.0       True    1024
# 24  process   faas  False                     20.0      False    1024
# 25  process   faas   True                     20.0      False    1024
# 26  process   faas  False                    150.0       True    1024
# 27  process   faas   True                    150.0       True    1024
# 28  process   faas  False                    150.0      False    1024
# 29  process   faas   True                    150.0      False    1024
# 30  process   faas  False                      0.0      False    8192
# 31  process   faas   True                      0.0      False    8192
# 32  process   faas  False                   9500.0       True    8192
# 33  process   faas   True                   9500.0       True    8192
# 34  process   faas  False                   9500.0      False    8192
# 35  process   faas   True                   9500.0      False    8192
# 36  process   faas  False                  76000.0       True    8192
# 37  process   faas   True                  76000.0       True    8192
# 38  process   faas  False                  76000.0      False    8192
# 39  process   faas   True                  76000.0      False    8192
#
#         t_kernel         t_kv
# 0      76.981445     0.016357
# 1      76.063721     0.007080
# 2      76.574951     0.017334
# 3      75.884521     0.008667
# 4      76.760742     0.032471
# 5      75.824707     0.016724
# 6      76.524170     0.020264
# 7      75.857666     0.008545
# 8      76.529785     0.032715
# 9      75.806030     0.018433
# 10  37888.618408     0.016113
# 11  37884.385010     0.007568
# 12  37896.167480     0.026367
# 13  37887.932373     0.016235
# 14  37890.059082     0.042969
# 15  37888.608887     0.030518
# 16  37885.913574     0.024902
# 17  37887.281616     0.015381
# 18  37899.158203     0.065430
# 19  37891.921143     0.041748
# 20     77.046631    39.060791
# 21     75.798584    11.521973
# 22     76.538574    41.569580
# 23     75.884033    11.567017
# 24     76.641846    57.482422
# 25     76.108765    22.531250
# 26     76.491699    38.760254
# 27     75.795044    10.762329
# 28     76.723877    55.168213
# 29     75.859375    21.664795
# 30  37888.450928  1769.757324
# 31  37889.521851   490.282959
# 32  37897.701904  1796.608643
# 33  37894.819702   541.268188
# 34  37897.142578  2269.233887
# 35  37896.585449  1018.841431
# 36  37897.607910  1820.097656
# 37  37890.373657   550.320435
# 38  37889.542725  2183.890625
# 39  37893.049194  1041.642944

# %% [markdown]
# # Plots

# %% [markdown]
# ## Time Breakdown

# %% [markdown]
# ### Setup and Funcs

# %%
# Get a plottable series for the given configuration (outputs always have only rows for keyTimes)
# All times are converted to pct of e2e
def getBreakdownPlottable(allDF, mode, warm, size, preTime, preInline):
    if size == 'small':
        dim = 1024
    elif size == 'large':
        dim = 8192
        
    if preTime is None:
        preTime = 0.0
    elif preTime == 'low':
        if size == 'small':
            preTime = 20.0
        else:
            preTime = 9500.0
    elif preTime == 'high':
        if size == 'small':
            preTime = 150.0
        else:
            preTime = 76000.0

    times = allDF.loc[ (allDF['mode'] == mode) & (allDF['warm'] == warm) & (allDF['matDim'] == dim) &
                    (allDF['t_preprocess_configured'] == preTime) & (allDF['preInline'] == preInline)]

    if len(times) == 0:
        raise RuntimeError("No experiment matched configuration")
    elif len(times) != 1:
        raise RuntimeError("configuration wasn't unique\n" + str(times[configCols + ['name']]))

    times = times.iloc[0]
    pcts = (times[keyTimes] / times['t_e2e']) * 100
    
    final = pd.DataFrame([times, pcts], index=['ms', 'pct'])
    
#     final['Preprocess'] = final['t_preInit'] + final['t_preprocess_configured']
    final['Preprocess'] = final['t_preprocess_configured']
    final['Pre Init'] = final['t_preInit']

    #     final['Kernel'] = final['t_kernInit'] + final['t_kernel']
    final['Kernel'] = final['t_kernel']
    final['Kernel Init'] = final['t_kernInit']
    
    final['Other'] = final['t_uncounted'] + final['t_controlPlane']
    
    # Human Readable Names
    final.rename(inplace = True, columns = {'t_cudaMM' : "GPU MM", 't_kv' : 'KV Read/Write',
                                          't_cudaCopy' : "GPU Read/Write"})
    
 
    # Re-Order for exposition
    final = final[['Other', 'KV Read/Write', 'GPU MM', 'GPU Read/Write', 'Pre Init', 'Preprocess', 'Kernel Init', 'Kernel']]
    
    return final

# %%
def getLimits(df):
    # Time contribution of the non-kernel parts (for the biggest benchmark)
    extraHeight = df.drop(columns=['Kernel']).transpose().sum().max()
    totalHeight = df.transpose().sum().max()
    
    return ((0, extraHeight*1.25), (totalHeight * .75,totalHeight*1.1))


def _preparePltDF(dfs, names, metric, overheadOnly=False):
    if metric == "percent":
        pltDF = pd.DataFrame([ d.loc['pct']  for d in dfs ], index=names)
    elif metric == 'time':
        pltDF = pd.DataFrame([ d.loc['ms'] for d in dfs ], index=names)

    if overheadOnly:
        pltDF.drop(columns=['Kernel'], inplace=True)
        pltDF.drop(columns=['Preprocess'], inplace=True)
        
    return pltDF

def plotBreakdownBroken(dfs, names, metric, limits, title='', overheadOnly=False):
    pltDF = _preparePltDF(dfs,names,metric,overheadOnly)
    
    fig, (ax1, ax2) = plt.subplots(2,1,sharex=True, gridspec_kw={"height_ratios" : [0.25, 1]})
    
    ax1.spines['bottom'].set_visible(False)
    ax1.tick_params(axis='x',which='both',bottom=False)
    ax2.spines['top'].set_visible(False)
    
    ax2.set_ylim(limits[0][0], limits[0][1])
    ax1.set_ylim(limits[1][0], limits[1][1])
    
    pltDF.plot(kind='bar', stacked=True, ax=ax1, legend=None)
    pltDF.plot(kind='bar', stacked=True, ax=ax2, legend=None)
    
    make_hatches(ax1, pltDF)
    make_hatches(ax2, pltDF)
    
    # sets the slash on the break on the axis
    for tick in ax2.get_xticklabels():
        tick.set_rotation(0)
    d = .015  
    kwargs = dict(transform=ax1.transAxes, color='k', clip_on=False)
    ax1.plot((-d, +d), (-d, +d), **kwargs)      
    ax1.plot((1 - d, 1 + d), (-d, +d), **kwargs)
    kwargs.update(transform=ax2.transAxes)  
    ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)  
    ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)

    if metric == 'percent':
#         ax1.set_ylabel("Percent of Total Runtime")
        ax2.set_ylabel("Percent of Total Runtime")
    elif metric == 'time':
        ax2.set_ylabel("Time (ms)")
        ax2.yaxis.set_label_coords(-0.1,0.65)
    
    ax1.set_title(title)
    
    ax1.set_xlabel("")
    ax2.set_xlabel("")
    ax1.tick_params(axis='x', rotation=0)
    ax2.tick_params(axis='x', rotation=0)
    
    # Skinny legend
#     ax1.legend(loc='center left', bbox_to_anchor=[1,0.5])
    # Regular readable legend off to the side
    ax1.legend(loc='center left', bbox_to_anchor=[1,-1])
    
    return fig

    
def plotBreakdown(dfs, names, metric, title='', overheadOnly=False):
    pltDF = _preparePltDF(dfs,names,metric,overheadOnly)
    
    ax = pltDF.plot.bar(stacked=True, legend=None)
    make_hatches(ax, pltDF)

    if metric == 'percent':
        ax.set_ylabel("Percent of Total Runtime")
    elif metric == 'time':
        ax.set_ylabel("Time (ms)")
        
    ax.set_title(title)
    ax.set_xlabel("")
    ax.tick_params(axis='x', rotation=0)

    # Skinny legend
#     ax.legend(loc='center left', bbox_to_anchor=[1,0.5], ncol=6)
    # Regular readable legend off to the side
    ax.legend(loc='center left', bbox_to_anchor=[1,0.5])

    return ax.get_figure()

# %%
p1 = getBreakdownPlottable(faasDF, mode='process', warm=False, size='small', preTime=None, preInline=False)
p2 = getBreakdownPlottable(faasDF, mode='process', warm=True, size='small', preTime=None, preInline=False)
p3 = getBreakdownPlottable(kaasDF, mode='process', warm=False, size='small', preTime=None, preInline=False)
p4 = getBreakdownPlottable(kaasDF, mode='process', warm=True, size='small', preTime=None, preInline=False)

pltDF = pd.DataFrame([p1.loc['ms'], p2.loc['ms']], index=['KaaS', 'FaaS'])
# fig = plotBreakdown([p1,p2], ['FaaS\n(cold)', 'KaaS\n(cold)'], metric="time", overheadOnly=True)
fig = plotBreakdownBroken([p1,p2,p3,p4],
                          ['FaaS\n(cold)', 'FaaS\n(warm)', 'KaaS\n(cold)', 'KaaS\n(warm)'],
                          "percent",
                          [[0,50],[51,100]],
#                           [[0,65],[350,390]],
                          overheadOnly=True)

# fig = plotBreakdown([p1,p2],
#                    ['FaaS', 'KaaS'],
#                    'percent',
#                    title="Warm Start",
#                    overheadOnly=True)
# # pltDF = pd.DataFrame([p1.loc['ms']], index=['KaaS'])
# # fig = plotBreakdown([p1], ['Large'], metric="percent", overheadOnly=True)

fig.savefig("/Users/nathanp/Downloads/microSmall.png", dpi=300, bbox_inches='tight')
